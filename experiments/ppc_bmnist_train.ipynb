# %%
# %cd ..
# Out:
# /home/eli/AnacondaProjects/ppc_experiments

# %%
import argparse
import collections
import numpy as np
import pyro
import torch
import data_loader.data_loaders as module_data
import model.loss as module_loss
import model.metric as module_metric
import model.model as module_arch
from parse_config import ConfigParser
import trainer.trainer as module_trainer

# %%
# pyro.enable_validation(True)
# torch.autograd.set_detect_anomaly(True)

# %%
# fix random seeds for reproducibility
SEED = 123
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(SEED)

# %%
def main(config):
    logger = config.get_logger('train')

    # setup data_loader instances
    data_loader = config.init_obj('data_loader', module_data)
    valid_data_loader = data_loader.split_validation()

    # build model architecture, then print to console
    model = config.init_obj('arch', module_arch)
    logger.info(model)

    # get function handles of metrics
    metrics = [getattr(module_metric, met) for met in config['metrics']]

    # build optimizer.
    optimizer = config.init_obj('optimizer', pyro.optim)

    # build trainer
    # kwargs = config['trainer'].pop('args')
    trainer = config.init_obj('trainer', module_trainer, model, metrics, optimizer,
                              config=config, data_loader=data_loader,
                              valid_data_loader=valid_data_loader,
                              lr_scheduler=None)

    return trainer

# %%
from utils import read_json

config = read_json("experiments/ppc_bmnist_config.json")
config = ConfigParser(config)
trainer = main(config)
trainer.train()
# Out:
# BouncingMnistPpc(
#   (decoder): DigitsDecoder(
#     (decoder): Sequential(
#       (0): Linear(in_features=10, out_features=200, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=200, out_features=400, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=400, out_features=784, bias=True)
#       (5): Sigmoid()
#     )
#   )
#   (digit_features): DigitFeatures()
#   (digit_positions): DigitPositions()
#   (graph): GraphicalModel()
# )
# Trainable parameters: 396984
# Initialize particles: train batch 0
# Initialize particles: train batch 1
# Initialize particles: train batch 2
# Initialize particles: train batch 3
# Initialize particles: train batch 4
# Initialize particles: train batch 5
# Initialize particles: train batch 6
# Initialize particles: train batch 7
# Initialize particles: train batch 8
# Initialize particles: train batch 9
# Initialize particles: train batch 10
# Initialize particles: train batch 11
# Initialize particles: train batch 12
# Initialize particles: train batch 13
# Initialize particles: train batch 14
# Initialize particles: train batch 15
# Initialize particles: train batch 16
# Initialize particles: train batch 17
# Initialize particles: train batch 18
# Initialize particles: train batch 19
# Initialize particles: train batch 20
# Initialize particles: train batch 21
# Initialize particles: train batch 22
# Initialize particles: train batch 23
# Initialize particles: train batch 24
# Initialize particles: train batch 25
# Initialize particles: train batch 26
# Initialize particles: train batch 27
# Initialize particles: train batch 28
# Initialize particles: train batch 29
# Initialize particles: train batch 30
# Initialize particles: train batch 31
# Initialize particles: train batch 32
# Initialize particles: train batch 33
# Initialize particles: train batch 34
# Initialize particles: train batch 35
# Initialize particles: train batch 36
# Initialize particles: train batch 37
# Initialize particles: train batch 38
# Initialize particles: train batch 39
# Initialize particles: train batch 40
# Initialize particles: train batch 41
# Initialize particles: train batch 42
# Initialize particles: train batch 43
# Initialize particles: train batch 44
# Initialize particles: train batch 45
# Initialize particles: train batch 46
# Initialize particles: train batch 47
# Initialize particles: train batch 48
# Initialize particles: train batch 49
# Initialize particles: train batch 50
# Initialize particles: train batch 51
# Initialize particles: train batch 52
# Initialize particles: train batch 53
# Initialize particles: train batch 54
# Initialize particles: train batch 55
# Initialize particles: train batch 56
# Initialize particles: train batch 57
# Initialize particles: train batch 58
# Initialize particles: train batch 59
# Initialize particles: train batch 60
# Initialize particles: train batch 61
# Initialize particles: train batch 62
# Initialize particles: train batch 63
# Initialize particles: train batch 64
# Initialize particles: train batch 65
# Initialize particles: train batch 66
# Initialize particles: train batch 67
# Initialize particles: train batch 68
# Initialize particles: train batch 69
# Initialize particles: train batch 70
# Initialize particles: train batch 71
# Initialize particles: train batch 72
# Initialize particles: train batch 73
# Initialize particles: train batch 74
# Initialize particles: train batch 75
# Initialize particles: train batch 76
# Initialize particles: train batch 77
# Initialize particles: train batch 78
# Initialize particles: train batch 79
# Initialize particles: train batch 80
# Initialize particles: train batch 81
# Initialize particles: train batch 82
# Initialize particles: train batch 83
# Initialize particles: train batch 84
# Initialize particles: train batch 85
# Initialize particles: train batch 86
# Initialize particles: train batch 87
# Initialize particles: train batch 88
# Initialize particles: train batch 89
# Initialize particles: train batch 90
# Initialize particles: train batch 91
# Initialize particles: train batch 92
# Initialize particles: train batch 93
# Initialize particles: train batch 94
# Initialize particles: train batch 95
# Initialize particles: train batch 96
# Initialize particles: train batch 97
# Initialize particles: train batch 98
# Initialize particles: train batch 99
# Initialize particles: train batch 100
# Initialize particles: train batch 101
# Initialize particles: train batch 102
# Initialize particles: train batch 103
# Initialize particles: train batch 104
# Initialize particles: train batch 105
# Initialize particles: train batch 106
# Initialize particles: train batch 107
# Initialize particles: train batch 108
# Initialize particles: train batch 109
# Initialize particles: train batch 110
# Initialize particles: train batch 111
# Initialize particles: train batch 112
# Initialize particles: train batch 113
# Initialize particles: train batch 114
# Initialize particles: train batch 115
# Initialize particles: train batch 116
# Initialize particles: train batch 117
# Initialize particles: train batch 118
# Initialize particles: train batch 119
# Initialize particles: train batch 120
# Initialize particles: train batch 121
# Initialize particles: train batch 122
# Initialize particles: train batch 123
# Initialize particles: train batch 124
# Initialize particles: train batch 125
# Initialize particles: train batch 126
# Initialize particles: train batch 127
# Initialize particles: train batch 128
# Initialize particles: train batch 129
# Initialize particles: train batch 130
# Initialize particles: train batch 131
# Initialize particles: train batch 132
# Initialize particles: train batch 133
# Initialize particles: train batch 134
# Initialize particles: train batch 135
# Initialize particles: train batch 136
# Initialize particles: train batch 137
# Initialize particles: train batch 138
# Initialize particles: train batch 139
# Initialize particles: train batch 140
# Initialize particles: train batch 141
# Initialize particles: train batch 142
# Initialize particles: train batch 143
# Initialize particles: train batch 144
# Initialize particles: train batch 145
# Initialize particles: train batch 146
# Initialize particles: train batch 147
# Initialize particles: train batch 148
# Initialize particles: train batch 149
# Initialize particles: train batch 150
# Initialize particles: train batch 151
# Initialize particles: train batch 152
# Initialize particles: train batch 153
# Initialize particles: train batch 154
# Initialize particles: train batch 155
# Initialize particles: train batch 156
# Initialize particles: train batch 157
# Initialize particles: train batch 158
# Initialize particles: train batch 159
# Initialize particles: train batch 160
# Initialize particles: train batch 161
# Initialize particles: train batch 162
# Initialize particles: train batch 163
# Initialize particles: train batch 164
# Initialize particles: train batch 165
# Initialize particles: train batch 166
# Initialize particles: train batch 167
# Initialize particles: train batch 168
# Initialize particles: train batch 169
# Initialize particles: train batch 170
# Initialize particles: train batch 171
# Initialize particles: train batch 172
# Initialize particles: train batch 173
# Initialize particles: train batch 174
# Initialize particles: train batch 175
# Initialize particles: train batch 176
# Initialize particles: train batch 177
# Initialize particles: train batch 178
# Initialize particles: train batch 179
# Initialize particles: train batch 180
# Initialize particles: train batch 181
# Initialize particles: train batch 182
# Initialize particles: train batch 183
# Initialize particles: train batch 184
# Initialize particles: train batch 185
# Initialize particles: train batch 186
# Initialize particles: train batch 187
# Initialize particles: train batch 188
# Initialize particles: train batch 189
# Initialize particles: train batch 190
# Initialize particles: train batch 191
# Initialize particles: train batch 192
# Initialize particles: train batch 193
# Initialize particles: train batch 194
# Initialize particles: train batch 195
# Initialize particles: train batch 196
# Initialize particles: train batch 197
# Initialize particles: train batch 198
# Initialize particles: train batch 199
# Initialize particles: train batch 200
# Initialize particles: train batch 201
# Initialize particles: train batch 202
# Initialize particles: train batch 203
# Initialize particles: train batch 204
# Initialize particles: train batch 205
# Initialize particles: train batch 206
# Initialize particles: train batch 207
# Initialize particles: train batch 208
# Initialize particles: train batch 209
# Initialize particles: train batch 210
# Initialize particles: train batch 211
# Initialize particles: train batch 212
# Initialize particles: train batch 213
# Initialize particles: train batch 214
# Initialize particles: train batch 215
# Initialize particles: train batch 216
# Initialize particles: train batch 217
# Initialize particles: train batch 218
# Initialize particles: train batch 219
# Initialize particles: train batch 220
# Initialize particles: train batch 221
# Initialize particles: train batch 222
# Initialize particles: train batch 223
# Initialize particles: train batch 224
# Initialize particles: train batch 225
# Initialize particles: train batch 226
# Initialize particles: train batch 227
# Initialize particles: train batch 228
# Initialize particles: train batch 229
# Initialize particles: train batch 230
# Initialize particles: train batch 231
# Initialize particles: train batch 232
# Initialize particles: train batch 233
# Initialize particles: train batch 234
# Initialize particles: train batch 235
# Initialize particles: train batch 236
# Initialize particles: train batch 237
# Initialize particles: train batch 238
# Initialize particles: train batch 239
# Initialize particles: train batch 240
# Initialize particles: train batch 241
# Initialize particles: train batch 242
# Initialize particles: train batch 243
# Initialize particles: train batch 244
# Initialize particles: train batch 245
# Initialize particles: train batch 246
# Initialize particles: train batch 247
# Initialize particles: train batch 248
# Initialize particles: train batch 249
# Initialize particles: train batch 250
# Initialize particles: train batch 251
# Initialize particles: train batch 252
# Initialize particles: train batch 253
# Initialize particles: train batch 254
# Initialize particles: train batch 255
# Initialize particles: train batch 256
# Initialize particles: train batch 257
# Initialize particles: train batch 258
# Initialize particles: train batch 259
# Initialize particles: train batch 260
# Initialize particles: train batch 261
# Initialize particles: train batch 262
# Initialize particles: train batch 263
# Initialize particles: train batch 264
# Initialize particles: train batch 265
# Initialize particles: train batch 266
# Initialize particles: train batch 267
# Initialize particles: train batch 268
# Initialize particles: train batch 269
# Initialize particles: train batch 270
# Initialize particles: train batch 271
# Initialize particles: train batch 272
# Initialize particles: train batch 273
# Initialize particles: train batch 274
# Initialize particles: train batch 275
# Initialize particles: train batch 276
# Initialize particles: train batch 277
# Initialize particles: train batch 278
# Initialize particles: train batch 279
# Initialize particles: train batch 280
# Initialize particles: train batch 281
# Initialize particles: train batch 282
# Initialize particles: train batch 283
# Initialize particles: train batch 284
# Initialize particles: train batch 285
# Initialize particles: train batch 286
# Initialize particles: train batch 287
# Initialize particles: train batch 288
# Initialize particles: train batch 289
# Initialize particles: train batch 290
# Initialize particles: train batch 291
# Initialize particles: train batch 292
# Initialize particles: train batch 293
# Initialize particles: train batch 294
# Initialize particles: train batch 295
# Initialize particles: train batch 296
# Initialize particles: train batch 297
# Initialize particles: train batch 298
# Initialize particles: train batch 299
# Initialize particles: train batch 300
# Initialize particles: train batch 301
# Initialize particles: train batch 302
# Initialize particles: train batch 303
# Initialize particles: train batch 304
# Initialize particles: train batch 305
# Initialize particles: train batch 306
# Initialize particles: train batch 307
# Initialize particles: train batch 308
# Initialize particles: train batch 309
# Initialize particles: train batch 310
# Initialize particles: train batch 311
# Initialize particles: train batch 312
# Initialize particles: train batch 313
# Initialize particles: train batch 314
# Initialize particles: train batch 315
# Initialize particles: train batch 316
# Initialize particles: train batch 317
# Initialize particles: train batch 318
# Initialize particles: train batch 319
# Initialize particles: train batch 320
# Initialize particles: train batch 321
# Initialize particles: train batch 322
# Initialize particles: train batch 323
# Initialize particles: train batch 324
# Initialize particles: train batch 325
# Initialize particles: train batch 326
# Initialize particles: train batch 327
# Initialize particles: train batch 328
# Initialize particles: train batch 329
# Initialize particles: train batch 330
# Initialize particles: train batch 331
# Initialize particles: train batch 332
# Initialize particles: train batch 333
# Initialize particles: train batch 334
# Initialize particles: train batch 335
# Initialize particles: train batch 336
# Initialize particles: train batch 337
# Initialize particles: train batch 338
# Initialize particles: train batch 339
# Initialize particles: train batch 340
# Initialize particles: train batch 341
# Initialize particles: train batch 342
# Initialize particles: train batch 343
# Initialize particles: train batch 344
# Initialize particles: train batch 345
# Initialize particles: train batch 346
# Initialize particles: train batch 347
# Initialize particles: train batch 348
# Initialize particles: train batch 349
# Initialize particles: train batch 350
# Initialize particles: train batch 351
# Initialize particles: train batch 352
# Initialize particles: train batch 353
# Initialize particles: train batch 354
# Initialize particles: train batch 355
# Initialize particles: train batch 356
# Initialize particles: train batch 357
# Initialize particles: train batch 358
# Initialize particles: train batch 359
# Initialize particles: train batch 360
# Initialize particles: train batch 361
# Initialize particles: train batch 362
# Initialize particles: train batch 363
# Initialize particles: train batch 364
# Initialize particles: train batch 365
# Initialize particles: train batch 366
# Initialize particles: train batch 367
# Initialize particles: train batch 368
# Initialize particles: train batch 369
# Initialize particles: train batch 370
# Initialize particles: train batch 371
# Initialize particles: train batch 372
# Initialize particles: train batch 373
# Initialize particles: train batch 374
# Initialize particles: train batch 375
# Initialize particles: train batch 376
# Initialize particles: train batch 377
# Initialize particles: train batch 378
# Initialize particles: train batch 379
# Initialize particles: train batch 380
# Initialize particles: train batch 381
# Initialize particles: train batch 382
# Initialize particles: train batch 383
# Initialize particles: train batch 384
# Initialize particles: train batch 385
# Initialize particles: train batch 386
# Initialize particles: train batch 387
# Initialize particles: train batch 388
# Initialize particles: train batch 389
# Initialize particles: train batch 390
# Initialize particles: train batch 391
# Initialize particles: train batch 392
# Initialize particles: train batch 393
# Initialize particles: train batch 394
# Initialize particles: train batch 395
# Initialize particles: train batch 396
# Initialize particles: train batch 397
# Initialize particles: train batch 398
# Initialize particles: train batch 399
# Initialize particles: train batch 400
# Initialize particles: train batch 401
# Initialize particles: train batch 402
# Initialize particles: train batch 403
# Initialize particles: train batch 404
# Initialize particles: train batch 405
# Initialize particles: train batch 406
# Initialize particles: train batch 407
# Initialize particles: train batch 408
# Initialize particles: train batch 409
# Initialize particles: train batch 410
# Initialize particles: train batch 411
# Initialize particles: train batch 412
# Initialize particles: train batch 413
# Initialize particles: train batch 414
# Initialize particles: train batch 415
# Initialize particles: train batch 416
# Initialize particles: train batch 417
# Initialize particles: train batch 418
# Initialize particles: train batch 419
# Initialize particles: train batch 420
# Initialize particles: train batch 421
# Initialize particles: train batch 422
# Initialize particles: train batch 423
# Initialize particles: train batch 424
# Initialize particles: train batch 425
# Initialize particles: train batch 426
# Initialize particles: train batch 427
# Initialize particles: train batch 428
# Initialize particles: train batch 429
# Initialize particles: train batch 430
# Initialize particles: train batch 431
# Initialize particles: train batch 432
# Initialize particles: train batch 433
# Initialize particles: train batch 434
# Initialize particles: train batch 435
# Initialize particles: train batch 436
# Initialize particles: train batch 437
# Initialize particles: train batch 438
# Initialize particles: train batch 439
# Initialize particles: train batch 440
# Initialize particles: train batch 441
# Initialize particles: train batch 442
# Initialize particles: train batch 443
# Initialize particles: train batch 444
# Initialize particles: train batch 445
# Initialize particles: train batch 446
# Initialize particles: train batch 447
# Initialize particles: train batch 448
# Initialize particles: train batch 449
# Initialize particles: train batch 450
# Initialize particles: train batch 451
# Initialize particles: train batch 452
# Initialize particles: train batch 453
# Initialize particles: train batch 454
# Initialize particles: train batch 455
# Initialize particles: train batch 456
# Initialize particles: train batch 457
# Initialize particles: train batch 458
# Initialize particles: train batch 459
# Initialize particles: train batch 460
# Initialize particles: train batch 461
# Initialize particles: train batch 462
# Initialize particles: train batch 463
# Initialize particles: train batch 464
# Initialize particles: train batch 465
# Initialize particles: train batch 466
# Initialize particles: train batch 467
# Initialize particles: train batch 468
# Initialize particles: train batch 469
# Initialize particles: train batch 470
# Initialize particles: train batch 471
# Initialize particles: train batch 472
# Initialize particles: train batch 473
# Initialize particles: train batch 474
# Initialize particles: train batch 475
# Initialize particles: train batch 476
# Initialize particles: train batch 477
# Initialize particles: train batch 478
# Initialize particles: train batch 479
# Initialize particles: train batch 480
# Initialize particles: train batch 481
# Initialize particles: train batch 482
# Initialize particles: train batch 483
# Initialize particles: train batch 484
# Initialize particles: train batch 485
# Initialize particles: train batch 486
# Initialize particles: train batch 487
# Initialize particles: train batch 488
# Initialize particles: train batch 489
# Initialize particles: train batch 490
# Initialize particles: train batch 491
# Initialize particles: train batch 492
# Initialize particles: train batch 493
# Initialize particles: train batch 494
# Initialize particles: train batch 495
# Initialize particles: train batch 496
# Initialize particles: train batch 497
# Initialize particles: train batch 498
# Initialize particles: train batch 499
# Initialize particles: train batch 500
# Initialize particles: train batch 501
# Initialize particles: train batch 502
# Initialize particles: train batch 503
# Initialize particles: train batch 504
# Initialize particles: train batch 505
# Initialize particles: train batch 506
# Initialize particles: train batch 507
# Initialize particles: train batch 508
# Initialize particles: train batch 509
# Initialize particles: train batch 510
# Initialize particles: train batch 511
# Initialize particles: train batch 512
# Initialize particles: train batch 513
# Initialize particles: train batch 514
# Initialize particles: train batch 515
# Initialize particles: train batch 516
# Initialize particles: train batch 517
# Initialize particles: train batch 518
# Initialize particles: train batch 519
# Initialize particles: train batch 520
# Initialize particles: train batch 521
# Initialize particles: train batch 522
# Initialize particles: train batch 523
# Initialize particles: train batch 524
# Initialize particles: train batch 525
# Initialize particles: train batch 526
# Initialize particles: train batch 527
# Initialize particles: train batch 528
# Initialize particles: train batch 529
# Initialize particles: train batch 530
# Initialize particles: train batch 531
# Initialize particles: train batch 532
# Initialize particles: train batch 533
# Initialize particles: train batch 534
# Initialize particles: train batch 535
# Initialize particles: train batch 536
# Initialize particles: train batch 537
# Initialize particles: train batch 538
# Initialize particles: train batch 539
# Initialize particles: train batch 540
# Initialize particles: train batch 541
# Initialize particles: train batch 542
# Initialize particles: train batch 543
# Initialize particles: train batch 544
# Initialize particles: train batch 545
# Initialize particles: train batch 546
# Initialize particles: train batch 547
# Initialize particles: train batch 548
# Initialize particles: train batch 549
# Initialize particles: train batch 550
# Initialize particles: train batch 551
# Initialize particles: train batch 552
# Initialize particles: train batch 553
# Initialize particles: train batch 554
# Initialize particles: train batch 555
# Initialize particles: train batch 556
# Initialize particles: train batch 557
# Initialize particles: train batch 558
# Initialize particles: train batch 559
# Initialize particles: train batch 560
# Initialize particles: train batch 561
# Initialize particles: train batch 562
# Initialize particles: valid batch 0
# Initialize particles: valid batch 1
# Initialize particles: valid batch 2
# Initialize particles: valid batch 3
# Initialize particles: valid batch 4
# Initialize particles: valid batch 5
# Initialize particles: valid batch 6
# Initialize particles: valid batch 7
# Initialize particles: valid batch 8
# Initialize particles: valid batch 9
# Initialize particles: valid batch 10
# Initialize particles: valid batch 11
# Initialize particles: valid batch 12
# Initialize particles: valid batch 13
# Initialize particles: valid batch 14
# Initialize particles: valid batch 15
# Initialize particles: valid batch 16
# Initialize particles: valid batch 17
# Initialize particles: valid batch 18
# Initialize particles: valid batch 19
# Initialize particles: valid batch 20
# Initialize particles: valid batch 21
# Initialize particles: valid batch 22
# Initialize particles: valid batch 23
# Initialize particles: valid batch 24
# Initialize particles: valid batch 25
# Initialize particles: valid batch 26
# Initialize particles: valid batch 27
# Initialize particles: valid batch 28
# Initialize particles: valid batch 29
# Initialize particles: valid batch 30
# Initialize particles: valid batch 31
# Initialize particles: valid batch 32
# Initialize particles: valid batch 33
# Initialize particles: valid batch 34
# Initialize particles: valid batch 35
# Initialize particles: valid batch 36
# Initialize particles: valid batch 37
# Initialize particles: valid batch 38
# Initialize particles: valid batch 39
# Initialize particles: valid batch 40
# Initialize particles: valid batch 41
# Initialize particles: valid batch 42
# Initialize particles: valid batch 43
# Initialize particles: valid batch 44
# Initialize particles: valid batch 45
# Initialize particles: valid batch 46
# Initialize particles: valid batch 47
# Initialize particles: valid batch 48
# Initialize particles: valid batch 49
# Initialize particles: valid batch 50
# Initialize particles: valid batch 51
# Initialize particles: valid batch 52
# Initialize particles: valid batch 53
# Initialize particles: valid batch 54
# Initialize particles: valid batch 55
# Initialize particles: valid batch 56
# Initialize particles: valid batch 57
# Initialize particles: valid batch 58
# Initialize particles: valid batch 59
# Initialize particles: valid batch 60
# Initialize particles: valid batch 61
# Initialize particles: valid batch 62
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 6
#       4 config = ConfigParser(config)
#       5 trainer = main(config)
# ----> 6 trainer.train()
#
# File ~/AnacondaProjects/ppc_experiments/trainer/trainer.py:180, in PpcTrainer.train(self, profiler)
#     178 self.train_particles = self.train_particles.to(self.device)
#     179 self.valid_particles = self.valid_particles.to(self.device)
# --> 180 super().train(profiler=profiler)
#
# File ~/AnacondaProjects/ppc_experiments/base/base_trainer.py:77, in BaseTrainer.train(self, profiler)
#      75 if profiler is not None:
#      76     profiler.step()
# ---> 77 result = self._train_epoch(epoch)
#      79 # save logged informations into log dict
#      80 log = {'epoch': epoch}
#
# File ~/AnacondaProjects/ppc_experiments/trainer/trainer.py:241, in PpcTrainer._train_epoch(self, epoch)
#     238 for batch_idx, (data, target) in enumerate(self.data_loader):
#     239     data = data.to(self.device)
# --> 241     loss, log_weight = self._ppc_step(batch_idx, data)
#     243     self.writer.set_step((epoch - 1) * self.len_epoch + batch_idx)
#     244     self.train_metrics.update('loss', loss.item())
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:328, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     326 dynamic_ctx.__enter__()
#     327 try:
# --> 328     return fn(*args, **kwargs)
#     329 finally:
#     330     set_eval_frame(prior)
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:490, in catch_errors_wrapper.<locals>.catch_errors(frame, cache_entry, frame_state)
#     487             return hijacked_callback(frame, cache_entry, hooks, frame_state)
#     489 with compile_lock, _disable_current_modes():
# --> 490     return callback(frame, cache_entry, hooks, frame_state)
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/convert_frame.py:641, in convert_frame.<locals>._convert_frame(frame, cache_size, hooks, frame_state)
#     639 counters["frames"]["total"] += 1
#     640 try:
# --> 641     result = inner_convert(frame, cache_size, hooks, frame_state)
#     642     counters["frames"]["ok"] += 1
#     643     return result
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/convert_frame.py:133, in wrap_convert_context.<locals>._fn(*args, **kwargs)
#     131 cleanup = setup_compile_debug()
#     132 try:
# --> 133     return fn(*args, **kwargs)
#     134 finally:
#     135     cleanup.close()
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/convert_frame.py:389, in convert_frame_assert.<locals>._convert_frame_assert(frame, cache_entry, hooks, frame_state)
#     376 compile_id = CompileId(frame_id, frame_compile_id)
#     378 signpost_event(
#     379     "dynamo",
#     380     "_convert_frame_assert._compile",
#    (...)
#     386     },
#     387 )
# --> 389 return _compile(
#     390     frame.f_code,
#     391     frame.f_globals,
#     392     frame.f_locals,
#     393     frame.f_builtins,
#     394     compiler_fn,
#     395     one_graph,
#     396     export,
#     397     export_constraints,
#     398     hooks,
#     399     cache_size,
#     400     frame,
#     401     frame_state=frame_state,
#     402     compile_id=compile_id,
#     403 )
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/convert_frame.py:569, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_size, frame, frame_state, compile_id)
#     567 with compile_context(CompileContext(compile_id)):
#     568     try:
# --> 569         guarded_code = compile_inner(code, one_graph, hooks, transform)
#     570         return guarded_code
#     571     except (
#     572         Unsupported,
#     573         TorchRuntimeError,
#    (...)
#     578         ValidationException,
#     579     ) as e:
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/utils.py:189, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     187 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     188     t0 = time.time()
# --> 189     r = func(*args, **kwargs)
#     190     time_spent = time.time() - t0
#     191 compilation_time_metrics[key].append(time_spent)
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/convert_frame.py:491, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     489 for attempt in itertools.count():
#     490     try:
# --> 491         out_code = transform_code_object(code, transform)
#     492         orig_code_map[out_code] = code
#     493         break
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/bytecode_transformation.py:1028, in transform_code_object(code, transformations, safe)
#    1025 instructions = cleaned_instructions(code, safe)
#    1026 propagate_line_nums(instructions)
# -> 1028 transformations(instructions, code_options)
#    1029 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/convert_frame.py:458, in _compile.<locals>.transform(instructions, code_options)
#     456 try:
#     457     with tracing(tracer.output.tracing_context):
# --> 458         tracer.run()
#     459 except (exc.RestartAnalysis, exc.SkipFrame):
#     460     raise
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:2069, in InstructionTranslator.run(self)
#    2068 def run(self):
# -> 2069     super().run()
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:719, in InstructionTranslatorBase.run(self)
#     714 try:
#     715     self.output.push_tx(self)
#     716     while (
#     717         self.instruction_pointer is not None
#     718         and not self.output.should_exit
# --> 719         and self.step()
#     720     ):
#     721         pass
#     722 except BackendCompilerFailed:
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:683, in InstructionTranslatorBase.step(self)
#     679         unimplemented(f"missing: {inst.opname}")
#     680     TracingContext.set_current_loc(
#     681         self.f_code.co_filename, self.lineno, self.f_code.co_name
#     682     )
# --> 683     getattr(self, inst.opname)(inst)
#     685     return inst.opname != "RETURN_VALUE"
#     686 except Unsupported:
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:392, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     388 try:
#     389     TracingContext.set_current_loc(
#     390         self.f_code.co_filename, self.lineno, self.f_code.co_name
#     391     )
# --> 392     return inner_fn(self, inst)
#     393 except Unsupported as excp:
#     394     if self.has_backedge() and self.should_compile_partial_graph():
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:1723, in InstructionTranslatorBase.CALL(self, inst)
#    1721     args = args + contents[2:]
#    1722     kwargs = {}
# -> 1723 self.call_function(fn, args, kwargs)
#    1724 self.kw_names = None
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:557, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     555 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     556     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 557 self.push(fn.call_function(self, args, kwargs))
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/variables/functions.py:307, in UserMethodVariable.call_function(self, tx, args, kwargs)
#     299     if (
#     300         module_attr is not None
#     301         and module_attr.startswith("torch.nn.")
#     302         or self.is_constant
#     303     ):
#     304         return self.obj.call_method(
#     305             tx, self.fn.__name__, args, kwargs, constant=self.is_constant
#     306         ).add_options(self)
# --> 307 return super().call_function(tx, args, kwargs)
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/variables/functions.py:261, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     256     options = VariableTracker.propagate(self, args, kwargs.values())
#     257     return invoke_and_store_as_constant(
#     258         tx, self.fn, self.get_name(), options, args, kwargs
#     259     )
# --> 261 return super().call_function(tx, args, kwargs)
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/variables/functions.py:90, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#      87 def call_function(
#      88     self, tx, args: "List[VariableTracker]", kwargs: "Dict[str, VariableTracker]"
#      89 ) -> "VariableTracker":
# ---> 90     return tx.inline_user_function_return(
#      91         self, list(self.self_args()) + list(args), kwargs
#      92     )
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:593, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     591 state = self.copy_graphstate()
#     592 try:
# --> 593     result = InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#     594     self.output.guards.update(fn.guards)
#     595     return result
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:2174, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    2171 @classmethod
#    2172 def inline_call(cls, parent, func, args, kwargs):
#    2173     with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 2174         return cls.inline_call_(parent, func, args, kwargs)
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:2281, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    2279 try:
#    2280     with strict_ctx:
# -> 2281         tracer.run()
#    2282 except exc.SkipFrame as e:
#    2283     msg = f"SKIPPED INLINING {code}: {e}"
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:719, in InstructionTranslatorBase.run(self)
#     714 try:
#     715     self.output.push_tx(self)
#     716     while (
#     717         self.instruction_pointer is not None
#     718         and not self.output.should_exit
# --> 719         and self.step()
#     720     ):
#     721         pass
#     722 except BackendCompilerFailed:
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:683, in InstructionTranslatorBase.step(self)
#     679         unimplemented(f"missing: {inst.opname}")
#     680     TracingContext.set_current_loc(
#     681         self.f_code.co_filename, self.lineno, self.f_code.co_name
#     682     )
# --> 683     getattr(self, inst.opname)(inst)
#     685     return inst.opname != "RETURN_VALUE"
#     686 except Unsupported:
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:1104, in InstructionTranslatorBase.GET_ITER(self, inst)
#    1103 def GET_ITER(self, inst):
# -> 1104     self.call_function(BuiltinVariable(iter), [self.pop()], {})
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:557, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     555 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     556     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 557 self.push(fn.call_function(self, args, kwargs))
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/variables/builtin.py:618, in BuiltinVariable.call_function(self, tx, args, kwargs)
#     616 if handler:
#     617     try:
# --> 618         result = handler(tx, *args, **kwargs)
#     619         if result is not None:
#     620             return result.add_options(options)
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/variables/builtin.py:808, in BuiltinVariable._call_iter_tuple_list(self, tx, obj, *args, **kwargs)
#     803     else:
#     804         return cls(
#     805             [],
#     806             mutable_local=MutableLocal(),
#     807         )
# --> 808 elif obj.has_unpack_var_sequence(tx):
#     809     guards = set()
#     810     if obj.source and not is_constant_source(obj.source):
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/variables/base.py:292, in VariableTracker.has_unpack_var_sequence(self, tx)
#     290 def has_unpack_var_sequence(self, tx):
#     291     try:
# --> 292         self.unpack_var_sequence(tx)
#     293         return True
#     294     except NotImplementedError:
#
# File ~/miniforge3/envs/ppc/lib/python3.11/site-packages/torch/_dynamo/variables/nn_module.py:99, in NNModuleVariable.unpack_var_sequence(self, tx)
#      96         result.append(name_var)
#      97     return result
# ---> 99 assert isinstance(
#     100     base, (torch.nn.ModuleList, torch.nn.ParameterList, torch.nn.Sequential)
#     101 ), typestr(base)
#     102 assert self.source
#     103 result = []
#
# AssertionError: ParticleDict
#
# from user code:
#    File "/home/eli/AnacondaProjects/ppc_experiments/trainer/trainer.py", line 207, in _ppc_step
#     self._load_particles(batch_indices, train)
#   File "/home/eli/AnacondaProjects/ppc_experiments/trainer/trainer.py", line 192, in _load_particles
#     for site in particles:
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True

# %%
trained.model.eval()
trained.model.cpu()
