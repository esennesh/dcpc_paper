# %%
# %cd ..
# Out:
# /workspace/shai_hulud/ppc_experiments

# %%
import argparse
import collections
import lightning
import numpy as np
import pyro
import torch
import logger, train
# Out:
# Seed set to 123

# %%
# pyro.enable_validation(True)
# torch.autograd.set_detect_anomaly(True)

# %%
config, (data, model, trainer) = train.from_file("experiments/pgd_celeba_config.json")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
logger = config.get_logger('valid')

# %%
trainer.fit(model, data, ckpt_path="saved/models/Homoskedastic_CelebA_Ppc/0607_023010/checkpoint_99.ckpt")
# Out:
# Missing logger folder: saved/log/Homoskedastic_CelebA_Ppc/0607_154021/lightning_logs
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:653: Checkpoint directory /workspace/shai_hulud/ppc_experiments/saved/models/Homoskedastic_CelebA_Ppc/0607_154021 exists and is not empty.
# Restoring states from the checkpoint path at saved/models/Homoskedastic_CelebA_Ppc/0607_023010/checkpoint_99.ckpt
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:361: The dirpath has changed from '/workspace/shai_hulud/ppc_experiments/saved/models/Homoskedastic_CelebA_Ppc/0607_023010' to '/workspace/shai_hulud/ppc_experiments/saved/models/Homoskedastic_CelebA_Ppc/0607_154021', therefore `best_model_score`, `kth_best_model_path`, `kth_value`, `last_model_path` and `best_k_models` won't be reloaded. Only `best_model_path` will be reloaded.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
#   | Name       | Type         | Params
# --------------------------------------------
# 0 | graph      | GeneratorPpc | 357 K
# 1 | predictive | Predictive   | 0
# --------------------------------------------
# 357 K     Trainable params
# 0         Non-trainable params
# 357 K     Total params
# 1.430     Total estimated model params size (MB)
# Restored all states from the checkpoint at saved/models/Homoskedastic_CelebA_Ppc/0607_023010/checkpoint_99.ckpt
# Sanity Checking: |                                                                                            …
# `Trainer.fit` stopped: `max_epochs=100` reached.

# %%
model.graph.clear()
model.eval()
model.cuda()
# Out:
# LightningPpc(
#   (graph): GeneratorPpc(
#     (prior): GaussianPrior()
#     (likelihood): FixedVarianceDecoder(
#       (mean_network): NLVM(
#         (projection_layer): Projection(
#           (linear): Linear(in_features=64, out_features=1024, bias=True)
#           (deconv1): ConvTranspose2d(4, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (linear_bn): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (deconv1_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (deterministic_layer_1): Deterministic(
#           (conv): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (deterministic_layer_2): Deterministic(
#           (conv): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (output_layer): Output(
#           (output_layer): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#   )
#   (predictive): Predictive()
# )

# %%
xs, _, indices = list(data.val_dataloader())[0]
xs = xs.to(model.device)
model._load_particles(indices, False)

# %%
with model.graph.condition(z=model.graph.nodes['z']['value']) as predictive:
    x_hats = predictive(B=len(xs), mode="prior", P=model.num_particles).mean(dim=0)

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(nrows=4, ncols=20, sharex="all", sharey="all", layout="compressed")

for row in range(4):
    for col in range(20):
        orgs = data.reverse_transform(xs[row * 20 + col].detach().cpu()).transpose(0, -1)
        axes[row, col].imshow(orgs)
        axes[row, col].set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

fig.savefig("pgd_celeba_orgs.pdf", bbox_inches="tight")
plt.show()

# %%
fig, axes = plt.subplots(nrows=4, ncols=20, sharex="all", sharey="all", layout="compressed")

for row in range(4):
    for col in range(20):
        estimates = data.reverse_transform(x_hats[row * 20 + col].detach().cpu()).transpose(0, -1)
        axes[row, col].imshow(estimates)
        axes[row, col].set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

fig.savefig("pgd_celeba_recons.pdf", bbox_inches="tight")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
del xs
del x_hats

# %%
model.graph.clear()

# %%
posterior = {k: torch.cat((v.detach(), model.particles["valid"][k].detach()), dim=1)
             for k, v in model.particles["train"].items()}
x_hats = model.graph.predict(B=8, P=model.num_particles, **posterior)
x_hats = torch.flatten(x_hats, 0, 1)

# %%
fig, axes = plt.subplots(nrows=4, ncols=20, sharex="all", sharey="all", layout="compressed")

for row in range(4):
    for col in range(20):
        estimates = data.reverse_transform(x_hats[row * 20 + col].squeeze().detach().cpu()).transpose(0, -1)
        axes[row, col].imshow(estimates)
        axes[row, col].set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

fig.savefig("pgd_celeba_samples.pdf", bbox_inches="tight")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
del x_hats

# %%
SEEDS = [123, 456, 789, 101112, 131415]

# %%
LOG_LIKELIHOODS = torch.zeros(len(SEEDS), requires_grad=False)
MEAN_SQUARED_ERROR = torch.zeros(len(SEEDS), requires_grad=False)

# %%
with torch.no_grad():
    for (s, SEED) in enumerate(SEEDS):
        torch.manual_seed(SEED)
        np.random.seed(SEED)
        for b, (xs, target, indices) in enumerate(data.val_dataloader()):
            xs = xs.to(model.device)
            model._load_particles(indices, False)
            x_hats = model.graph(B=len(xs), mode="prior", P=model.num_particles)
            with model.graph.condition(X=xs) as predictive:
                trace, _ = predictive(B=len(xs), P=model.num_particles)
            LOG_LIKELIHOODS[s] += trace.nodes['X']['fn'].log_prob(xs).sum().cpu()
            MEAN_SQUARED_ERROR[s] += ((xs - x_hats) ** 2).sum(dim=0).mean().cpu()
    
            del xs
            del x_hats
            del trace
            del target
            del indices
            logger.info("Evaluated likelihood for valid batch %d under seed %s" % (b, s))
    
        LOG_LIKELIHOODS[s] /= len(data.val_dataloader().dataset) * model.num_particles
        MEAN_SQUARED_ERROR[s] /= len(data.val_dataloader().dataset) * model.num_particles
# Out:
# Evaluated likelihood for valid batch 0 under seed 0
# Evaluated likelihood for valid batch 1 under seed 0
# Evaluated likelihood for valid batch 2 under seed 0
# Evaluated likelihood for valid batch 3 under seed 0
# Evaluated likelihood for valid batch 4 under seed 0
# Evaluated likelihood for valid batch 5 under seed 0
# Evaluated likelihood for valid batch 6 under seed 0
# Evaluated likelihood for valid batch 7 under seed 0
# Evaluated likelihood for valid batch 8 under seed 0
# Evaluated likelihood for valid batch 9 under seed 0
# Evaluated likelihood for valid batch 10 under seed 0
# Evaluated likelihood for valid batch 11 under seed 0
# Evaluated likelihood for valid batch 12 under seed 0
# Evaluated likelihood for valid batch 13 under seed 0
# Evaluated likelihood for valid batch 14 under seed 0
# Evaluated likelihood for valid batch 15 under seed 0
# Evaluated likelihood for valid batch 16 under seed 0
# Evaluated likelihood for valid batch 17 under seed 0
# Evaluated likelihood for valid batch 18 under seed 0
# Evaluated likelihood for valid batch 19 under seed 0
# Evaluated likelihood for valid batch 0 under seed 1
# Evaluated likelihood for valid batch 1 under seed 1
# Evaluated likelihood for valid batch 2 under seed 1
# Evaluated likelihood for valid batch 3 under seed 1
# Evaluated likelihood for valid batch 4 under seed 1
# Evaluated likelihood for valid batch 5 under seed 1
# Evaluated likelihood for valid batch 6 under seed 1
# Evaluated likelihood for valid batch 7 under seed 1
# Evaluated likelihood for valid batch 8 under seed 1
# Evaluated likelihood for valid batch 9 under seed 1
# Evaluated likelihood for valid batch 10 under seed 1
# Evaluated likelihood for valid batch 11 under seed 1
# Evaluated likelihood for valid batch 12 under seed 1
# Evaluated likelihood for valid batch 13 under seed 1
# Evaluated likelihood for valid batch 14 under seed 1
# Evaluated likelihood for valid batch 15 under seed 1
# Evaluated likelihood for valid batch 16 under seed 1
# Evaluated likelihood for valid batch 17 under seed 1
# Evaluated likelihood for valid batch 18 under seed 1
# Evaluated likelihood for valid batch 19 under seed 1
# Evaluated likelihood for valid batch 0 under seed 2
# Evaluated likelihood for valid batch 1 under seed 2
# Evaluated likelihood for valid batch 2 under seed 2
# Evaluated likelihood for valid batch 3 under seed 2
# Evaluated likelihood for valid batch 4 under seed 2
# Evaluated likelihood for valid batch 5 under seed 2
# Evaluated likelihood for valid batch 6 under seed 2
# Evaluated likelihood for valid batch 7 under seed 2
# Evaluated likelihood for valid batch 8 under seed 2
# Evaluated likelihood for valid batch 9 under seed 2
# Evaluated likelihood for valid batch 10 under seed 2
# Evaluated likelihood for valid batch 11 under seed 2
# Evaluated likelihood for valid batch 12 under seed 2
# Evaluated likelihood for valid batch 13 under seed 2
# Evaluated likelihood for valid batch 14 under seed 2
# Evaluated likelihood for valid batch 15 under seed 2
# Evaluated likelihood for valid batch 16 under seed 2
# Evaluated likelihood for valid batch 17 under seed 2
# Evaluated likelihood for valid batch 18 under seed 2
# Evaluated likelihood for valid batch 19 under seed 2
# Evaluated likelihood for valid batch 0 under seed 3
# Evaluated likelihood for valid batch 1 under seed 3
# Evaluated likelihood for valid batch 2 under seed 3
# Evaluated likelihood for valid batch 3 under seed 3
# Evaluated likelihood for valid batch 4 under seed 3
# Evaluated likelihood for valid batch 5 under seed 3
# Evaluated likelihood for valid batch 6 under seed 3
# Evaluated likelihood for valid batch 7 under seed 3
# Evaluated likelihood for valid batch 8 under seed 3
# Evaluated likelihood for valid batch 9 under seed 3
# Evaluated likelihood for valid batch 10 under seed 3
# Evaluated likelihood for valid batch 11 under seed 3
# Evaluated likelihood for valid batch 12 under seed 3
# Evaluated likelihood for valid batch 13 under seed 3
# Evaluated likelihood for valid batch 14 under seed 3
# Evaluated likelihood for valid batch 15 under seed 3
# Evaluated likelihood for valid batch 16 under seed 3
# Evaluated likelihood for valid batch 17 under seed 3
# Evaluated likelihood for valid batch 18 under seed 3
# Evaluated likelihood for valid batch 19 under seed 3
# Evaluated likelihood for valid batch 0 under seed 4
# Evaluated likelihood for valid batch 1 under seed 4
# Evaluated likelihood for valid batch 2 under seed 4
# Evaluated likelihood for valid batch 3 under seed 4
# Evaluated likelihood for valid batch 4 under seed 4
# Evaluated likelihood for valid batch 5 under seed 4
# Evaluated likelihood for valid batch 6 under seed 4
# Evaluated likelihood for valid batch 7 under seed 4
# Evaluated likelihood for valid batch 8 under seed 4
# Evaluated likelihood for valid batch 9 under seed 4
# Evaluated likelihood for valid batch 10 under seed 4
# Evaluated likelihood for valid batch 11 under seed 4
# Evaluated likelihood for valid batch 12 under seed 4
# Evaluated likelihood for valid batch 13 under seed 4
# Evaluated likelihood for valid batch 14 under seed 4
# Evaluated likelihood for valid batch 15 under seed 4
# Evaluated likelihood for valid batch 16 under seed 4
# Evaluated likelihood for valid batch 17 under seed 4
# Evaluated likelihood for valid batch 18 under seed 4
# Evaluated likelihood for valid batch 19 under seed 4

# %%
LOG_LIKELIHOODS.mean(), LOG_LIKELIHOODS.std()
# Out:
# (tensor(-2562296.5000), tensor(12430.3037))

# %%
MEAN_SQUARED_ERROR.mean(), MEAN_SQUARED_ERROR.std()
# Out:
# (tensor(0.0006), tensor(3.4721e-07))

# %%
model.graph.clear()

# %%
x_hats = model.graph(B=data.batch_size, mode="prior", P=model.num_particles).view(data.batch_size * model.num_particles, 3, 32, 32)

# %%
fig, axes = plt.subplots(nrows=4, ncols=20, sharex="all", sharey="all", layout="compressed")

for row in range(4):
    for col in range(20):
        estimates = data.reverse_transform(x_hats[row * 20 + col].squeeze().detach().cpu()).transpose(0, -1)
        axes[row, col].imshow(estimates)
        axes[row, col].set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
xs, targets, indices = list(data.val_dataloader())[0]
xs = xs.to(model.device)
model.test_step((xs, targets, indices), 0)
# Out:
# {'ess': 1.0,
#  'log_joint': -2798297.0,
#  'log_marginal': -1757833.125,
#  'loss': tensor(1757833.1250, device='cuda:7'),
#  'fid': tensor(167.3400, device='cuda:7', dtype=torch.float64)}
